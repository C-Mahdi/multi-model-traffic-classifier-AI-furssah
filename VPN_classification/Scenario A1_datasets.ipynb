# %%
from scipy.io import arff
import pandas as pd

# Load ARFF file using scipy
data, meta = arff.loadarff('/dataset/TimeBasedFeatures-Dataset-15s-VPN.arff')

# Convert to pandas DataFrame
df = pd.DataFrame(data)

# Decode byte strings (especially in the 'class1' or any categorical column)
for col in df.select_dtypes(['object']).columns:
    df[col] = df[col].str.decode('utf-8')

# Display first rows
df.head()
# Out:
#      duration  total_fiat  total_biat   min_fiat   min_biat       max_fiat  \
# 0   9368711.0        16.0         4.0  1564818.0  1549373.0  190205.285714
# 1   7340238.0        18.0         4.0  1567554.0  1527893.0  165686.977273
# 2   4644225.0        29.0        15.0  1270547.0  1079974.0  165865.178571
# 3   4978735.0        19.0         8.0  2492050.0  2457286.0  239543.250000
# 4  11838189.0        19.0        10.0  3094089.0  3093543.0  243766.500000
#
#         max_biat      mean_fiat      mean_biat  flowPktsPerSecond  ...  \
# 0  203290.456522  389822.391917  370323.719754          10.353612  ...
# 1  186914.846154  317267.548742  304370.651301          11.580006  ...
# 2  195302.130435  329473.126261  300492.588227          11.412022  ...
# 3  276596.388889  612435.304238  628339.573544           8.034169  ...
# 4  295954.725000  599721.781709  625632.703972           7.602514  ...
#
#      std_flowiat  min_active   mean_active  max_active    std_active  \
# ...

# %%
print(df.columns)
# Out:
# Index(['duration', 'total_fiat', 'total_biat', 'min_fiat', 'min_biat',
#        'max_fiat', 'max_biat', 'mean_fiat', 'mean_biat', 'flowPktsPerSecond',
#        'flowBytesPerSecond', 'min_flowiat', 'max_flowiat', 'mean_flowiat',
#        'std_flowiat', 'min_active', 'mean_active', 'max_active', 'std_active',
#        'min_idle', 'mean_idle', 'max_idle', 'std_idle', 'class1'],
#       dtype='object')

# %%
# Count the occurrences of each class
print(df['class1'].value_counts())
# Out:
# VPN        9793
# Non-VPN    8965
# Name: class1, dtype: int64

# %%
df.to_csv('TimeBasedFeatures-Dataset-15s-VPN.csv', index=False)
print("CSV saved successfully.")
# Out:
# CSV saved successfully.

# %%
from scipy.io import arff
import pandas as pd

# Load ARFF file using scipy
data, meta = arff.loadarff('TimeBasedFeatures-Dataset-30s-VPN.arff')

# Convert to pandas DataFrame
df1 = pd.DataFrame(data)

# Decode byte strings (especially in the 'class1' or any categorical column)
for col in df1.select_dtypes(['object']).columns:
    df1[col] = df1[col].str.decode('utf-8')

# Display first rows
df1
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14646       332.0        -1.0        -1.0        -1.0        -1.0
# 14647       297.0        -1.0        -1.0        -1.0        -1.0
# 14648    251872.0        -1.0        -1.0        -1.0        -1.0
# 14649       304.0        -1.0        -1.0        -1.0        -1.0
# 14650       245.0        -1.0        -1.0        -1.0        -1.0
#
#             max_fiat       max_biat     mean_fiat     mean_biat  \
# 0      314115.301370  360993.158730  1.306745e+06  1.389355e+06
# ...

# %%
# Count the occurrences of each class
print(df1['class1'].value_counts())
# Out:
# VPN        7734
# Non-VPN    6917
# Name: class1, dtype: int64

# %%
df1.to_csv('TimeBasedFeatures-Dataset-30s-VPN.csv', index=False)
print("CSV saved successfully.")
# Out:
# CSV saved successfully.

# %%
import pandas as pd

# Read the ARFF file as raw text (manual approach)
with open('TimeBasedFeatures-Dataset-60s-VPN.arff', 'r') as f:
    lines = f.readlines()

# Find the start of data section
data_start = None
for i, line in enumerate(lines):
    if '@data' in line.lower():
        data_start = i + 1
        break

# Extract attribute lines and data lines
attribute_lines = lines[:data_start]
data_lines = lines[data_start:]

# Get attribute names
attributes = []
for line in attribute_lines:
    if line.lower().startswith('@attribute'):
        attr_name = line.split()[1].strip("'\"")
        attributes.append(attr_name)

# Create a clean list of data (replace '' or '?' with NaN)
clean_data = []
for line in data_lines:
    if line.strip() == '':
        continue  # skip empty lines
    line = line.strip().replace('?', 'nan').replace(',,', ',nan,')  # optional double commas
    # Ensure lines ending with comma get a NaN
    if line.endswith(','):
        line += 'nan'
    split_line = [x.strip() if x.strip() != '' else 'nan' for x in line.split(',')]
    clean_data.append(split_line)

# Create DataFrame
df2 = pd.DataFrame(clean_data, columns=attributes)

# Convert numeric columns
for col in df2.columns:
    df2[col] = pd.to_numeric(df2[col], errors='ignore')

df2
# Out:
#       duration min_fiat min_biat max_fiat max_biat mean_fiat mean_biat  \
# 0          nan      nan      nan      nan      nan       nan       nan
# 1           76       -1       -1       -1       -1         0         0
# 2           54       -1       -1       -1       -1         0         0
# 3           67       -1       -1       -1       -1         0         0
# 4           75       -1       -1       -1       -1         0         0
# ...        ...      ...      ...      ...      ...       ...       ...
# 15511      266       -1       -1       -1       -1         0         0
# 15512      250       -1       -1       -1       -1         0         0
# 15513      445       -1       -1       -1       -1         0         0
# 15514   183694       -1       -1       -1       -1         0         0
# 15515      328       -1       -1       -1       -1         0         0
#
#       std_fiat std_biat flowPktsPerSecond  ... std_flowiat min_active  \
# ...

# %%
# Count the occurrences of each class
print(df2['class1'].value_counts())
# Out:
# Non-VPN    8580
# VPN        6935
# nan           1
# Name: class1, dtype: int64

# %%
df1.to_csv('TimeBasedFeatures-Dataset-60s-VPN.csv', index=False)
print("CSV saved successfully.")
# Out:
# CSV saved successfully.

# %%
from scipy.io import arff
import pandas as pd

# Load ARFF file using scipy
data, meta = arff.loadarff('TimeBasedFeatures-Dataset-120s-VPN.arff')

# Convert to pandas DataFrame
df3 = pd.DataFrame(data)

# Decode byte strings (especially in the 'class1' or any categorical column)
for col in df3.select_dtypes(['object']).columns:
    df3[col] = df3[col].str.decode('utf-8')

# Display first rows
df3
# Out:
#           duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      117202678.0        17.0         4.0  35188437.0  35149142.0
# 1      119579137.0        16.0         4.0  35208950.0  35022877.0
# 2       90462788.0        20.0         5.0  24383019.0  24244301.0
# 3       65341087.0        18.0         5.0  26116331.0  25978548.0
# 4      119999180.0  29999272.0  29999277.0  30001029.0  30001305.0
# ...            ...         ...         ...         ...         ...
# 10777     136411.0        -1.0        -1.0        -1.0        -1.0
# 10778     219697.0        -1.0        -1.0        -1.0        -1.0
# 10779   20999326.0  20999326.0        -1.0  20999326.0        -1.0
# 10780     202627.0       146.0         0.0    100693.0    102049.0
# 10781     200759.0        88.0         0.0     99988.0    100746.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      4.742976e+05  5.578672e+05  2.502257e+06  2.693576e+06
# ...

# %%
# Count the occurrences of each class
print(df3['class1'].value_counts())
# Out:
# VPN        5631
# Non-VPN    5151
# Name: class1, dtype: int64

# %%
df1.to_csv('TimeBasedFeatures-Dataset-120s-VPN.csv', index=False)
print("CSV saved successfully.")
# Out:
# CSV saved successfully.

# %%
df_15s = pd.read_csv('TimeBasedFeatures-Dataset-15s-VPN.csv')
df_30s = pd.read_csv('TimeBasedFeatures-Dataset-30s-VPN.csv')
df_60s = pd.read_csv('TimeBasedFeatures-Dataset-60s-VPN.csv')
df_120s = pd.read_csv('TimeBasedFeatures-Dataset-120s-VPN.csv')

# %%
common_cols = set(df_15s.columns) & set(df_30s.columns) & set(df_60s.columns)
df_15s = df_15s[list(common_cols)]
df_30s = df_30s[list(common_cols)]
df_60s = df_60s[list(common_cols)]
df_120s = df_120s[list(common_cols)]

# %%
# Concatenate them vertically
df_combined = pd.concat([df_15s, df_30s, df_60s, df_120s], ignore_index=True)

# Optional: shuffle the combined dataset
df_combined = df_combined.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df_combined.to_csv('Combined_TimeBasedFeatures_Dataset.csv', index=False)
print("All datasets combined and saved as Combined_TimeBasedFeatures_Dataset.csv")
# Out:
# All datasets combined and saved as Combined_TimeBasedFeatures_Dataset.csv

# %%
df_combined
# Out:
#             max_fiat  total_fiat     mean_fiat  total_biat  min_flowiat  \
# 0      960168.806452    959557.0  4.132981e+02    958222.0      38638.0
# 1      960139.935484    959370.0  4.413439e+02    958686.0      38692.0
# 2       62013.879668        66.0  9.737783e+04        26.0          8.0
# 3        1436.000000      1436.0  0.000000e+00        -1.0       1436.0
# 4      110840.666667         2.0  1.578547e+05       220.0          2.0
# ...              ...         ...           ...         ...          ...
# 62706       0.000000        -1.0  0.000000e+00        -1.0     191536.0
# 62707       0.000000        -1.0  0.000000e+00        -1.0     562798.0
# 62708       0.000000        -1.0  0.000000e+00        -1.0     172466.0
# 62709  365340.439024         6.0  1.374729e+06        11.0          6.0
# 62710   19923.630565      3694.0  1.778823e+03        76.0          1.0
#
#         max_idle       max_biat   min_biat    std_active  max_flowiat  ...  \
# ...

# %%
print(df_combined['class1'].value_counts())
# Out:
# VPN        32995
# Non-VPN    29716
# Name: class1, dtype: int64

# %%
df_combined.to_csv('Combined_TimeBasedFeatures_Dataset.csv', index=False)
